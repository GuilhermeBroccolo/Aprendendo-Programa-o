# %% [markdown]
# # Primeiro código feito em Python
#
# ##### Neste exemplo abaixo fiz meu primeiro código em Python, utilizando a função "print"

# %%
print ("meu primeiro codigo")
# Out:
# meu primeiro codigo

# %% [markdown]
# #### Abaixo conferimos o meu segundo código em Python

# %%
string = "guilherme e gabriel aprendendo Python"
print (string)
# Out:
# guilherme e gabriel aprendendo Python
